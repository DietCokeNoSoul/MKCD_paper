# %%
from DrugReposition.data_process.properties import DrugProperty
from DrugReposition.data_process.similaritys import SimilarityFactory
from matplotlib import pyplot as plt
import numpy as np

# %%
RD=DrugProperty.get("disease")

# %%
from matplotlib.ticker import MaxNLocator
cnt=np.sum(RD,axis=1)
plt.rcParams['figure.figsize'] = (7, 4) 
plt.figure(dpi=300)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel("Number of related diseases (pcs)")
plt.ylabel("Drug distribution (%)")
plt.hist(cnt,bins=20,density=True,align="right",rwidth=0.9);

# %%
data=DrugProperty.get("pubchem")
cnt=np.sum(data,axis=1)
plt.rcParams['figure.figsize'] = (7, 4) 
plt.figure(dpi=300)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel("Number of related Chemical substructure (pcs)")
plt.ylabel("Drug distribution (%)")
plt.hist(cnt,bins=20,density=True,align="right",rwidth=0.9);

# %%
data=DrugProperty.get("domain")
cnt=np.sum(data,axis=1)
plt.rcParams['figure.figsize'] = (7, 4) 
plt.figure(dpi=300)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel("Number of related Protein domains (pcs)")
plt.ylabel("Drug distribution (%)")
plt.hist(cnt,bins=20,density=True,align="right",rwidth=0.9);

# %%
data=DrugProperty.get("go")
cnt=np.sum(data,axis=1)
plt.rcParams['figure.figsize'] = (7, 4) 
plt.figure(dpi=300)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel("Number of related Gene ontology items (pcs)")
plt.ylabel("Drug distribution (%)")
plt.hist(cnt,bins=20,density=True,align="right",rwidth=0.9);

# %%
RD=DrugProperty.get("disease")
RG=DrugProperty.get("go")
RP=DrugProperty.get("domain")
RC=DrugProperty.get("pubchem")

# %%
n_drug,n_disease=RD.shape
_,n_go=RG.shape
_,n_ch=RC.shape
_,n_pr=RP.shape
n_total=n_drug+n_disease+n_go+n_ch+n_pr
print(n_total)
# Out:
# 7940

# %%
e_rd=RD.sum(dtype=int)
e_go=RG.sum(dtype=int)
e_ch=RC.sum(dtype=int)
e_pr=RP.sum(dtype=int)
e_total=e_rd+e_go+e_ch+e_pr
print(e_total)
# Out:
# 162764

# %%
import pandas as pds

# %%
pds.Series([n_drug,n_disease,n_go,n_ch,n_pr],["Drug","Disease","Gene Ontology item","Chemical substructure","Protein domain"])
# Out:
# Drug                      763
# Disease                   681
# Gene Ontology item       4447
# Chemical substructure     623
# Protein domain           1426
# dtype: int64

# %%
pds.Series([e_rd,e_go,e_ch,e_pr],["Drug-Disease","Drug-Gene Ontology item","Drug-Chemical substructure","Drug-Protein domain"])
# Out:
# Drug-Disease                   3051
# Drug-Gene Ontology item       55918
# Drug-Chemical substructure    96202
# Drug-Protein domain            7593
# dtype: int64

# %%
plt.rcParams['figure.figsize'] = (7, 4) 
plt.figure(dpi=300)
sim=
plt.scatter(*np.where(RD>0),s=1)

# %%
plt.rcParams['figure.figsize'] = (7, 4) 
plt.figure(dpi=300)
plt.matshow(RD)
